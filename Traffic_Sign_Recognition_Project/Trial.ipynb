# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import cv2
from sklearn.utils import shuffle

# %%
train_dir = '../Traffic_Sign_Recognition_Project/'
test_dir = '../Traffic_Sign_Recognition_Project/'

IMG_SIZE = 75
BATCH_SIZE = 32
EPOCHS = 5

# %%
train_df = pd.read_csv("train.csv")
train_df = shuffle(train_df)
train_df.reset_index(inplace=True, drop=True)

# %%
train_df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     80      71       8       7      73      65       30
# 1     50      53       5       5      44      48        7
# 2     43      43       5       6      38      38        7
# 3     30      32       5       6      25      27        4
# 4     32      32       6       5      26      26       35
#
#                              Path
# 0  Train/30/00030_00004_00021.png
# 1   Train/7/00007_00047_00028.png
# 2   Train/7/00007_00025_00016.png
# 3   Train/4/00004_00056_00006.png
# 4  Train/35/00035_00025_00002.png

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
test_df.dtypes
# Out:
# Width       int64
# Height      int64
# Roi.X1      int64
# Roi.Y1      int64
# Roi.X2      int64
# Roi.Y2      int64
# ClassId     int64
# Path       object
# dtype: object

# %%
test_df['ClassId'] = test_df['ClassId'].astype(str)
train_df['ClassId'] = train_df['ClassId'].astype(str)

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.25
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=train_dir,
    x_col='Path',
    y_col='ClassId',
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE, IMG_SIZE),
    seed=42,
    shuffle=True,
    subset='training', 
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=train_dir,
    x_col="Path",
    y_col="ClassId",
    subset="validation",
    batch_size=BATCH_SIZE,
    seed=42,
    shuffle=True,
    class_mode="categorical",
    target_size=(IMG_SIZE,IMG_SIZE)
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=test_dir,
    x_col='Path',
    y_col='ClassId',
    batch_size=BATCH_SIZE,
    seed=42,
    shuffle=False,
    target_size=(IMG_SIZE, IMG_SIZE)    
)
# Out:
# Found 29407 validated image filenames belonging to 43 classes.
# Found 9802 validated image filenames belonging to 43 classes.
# Found 12630 validated image filenames belonging to 43 classes.

# %%
inception_model = tf.keras.applications.inception_v3.InceptionV3(include_top=False)
inception_model.trainable = True

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='input_layer')
x = inception_model(inputs, training=True)
x = layers.GlobalMaxPooling2D(name='global_avg_pool_layer')(x)
outputs = layers.Dense(43, activation='softmax', name='output_layer')(x)

new_model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
inception_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_1034 (Conv2D)            (None, None, None, 3 864         input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1034 (Batch (None, None, None, 3 96          conv2d_1034[0][0]
# __________________________________________________________________________________________________
# activation_1034 (Activation)    (None, None, None, 3 0           batch_normalization_1034[0][0]
# __________________________________________________________________________________________________
# conv2d_1035 (Conv2D)            (None, None, None, 3 9216        activation_1034[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1035 (Batch (None, None, None, 3 96          conv2d_1035[0][0]
# __________________________________________________________________________________________________
# activation_1035 (Activation)    (None, None, None, 3 0           batch_normalization_1035[0][0]
# __________________________________________________________________________________________________
# conv2d_1036 (Conv2D)            (None, None, None, 6 18432       activation_1035[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1036 (Batch (None, None, None, 6 192         conv2d_1036[0][0]
# __________________________________________________________________________________________________
# activation_1036 (Activation)    (None, None, None, 6 0           batch_normalization_1036[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, None, None, 6 0           activation_1036[0][0]
# __________________________________________________________________________________________________
# conv2d_1037 (Conv2D)            (None, None, None, 8 5120        max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1037 (Batch (None, None, None, 8 240         conv2d_1037[0][0]
# __________________________________________________________________________________________________
# activation_1037 (Activation)    (None, None, None, 8 0           batch_normalization_1037[0][0]
# __________________________________________________________________________________________________
# conv2d_1038 (Conv2D)            (None, None, None, 1 138240      activation_1037[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1038 (Batch (None, None, None, 1 576         conv2d_1038[0][0]
# __________________________________________________________________________________________________
# activation_1038 (Activation)    (None, None, None, 1 0           batch_normalization_1038[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, None, None, 1 0           activation_1038[0][0]
# __________________________________________________________________________________________________
# conv2d_1042 (Conv2D)            (None, None, None, 6 12288       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1042 (Batch (None, None, None, 6 192         conv2d_1042[0][0]
# __________________________________________________________________________________________________
# activation_1042 (Activation)    (None, None, None, 6 0           batch_normalization_1042[0][0]
# __________________________________________________________________________________________________
# conv2d_1040 (Conv2D)            (None, None, None, 4 9216        max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_1043 (Conv2D)            (None, None, None, 9 55296       activation_1042[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1040 (Batch (None, None, None, 4 144         conv2d_1040[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1043 (Batch (None, None, None, 9 288         conv2d_1043[0][0]
# __________________________________________________________________________________________________
# activation_1040 (Activation)    (None, None, None, 4 0           batch_normalization_1040[0][0]
# __________________________________________________________________________________________________
# activation_1043 (Activation)    (None, None, None, 9 0           batch_normalization_1043[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_99 (AveragePo (None, None, None, 1 0           max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_1039 (Conv2D)            (None, None, None, 6 12288       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_1041 (Conv2D)            (None, None, None, 6 76800       activation_1040[0][0]
# __________________________________________________________________________________________________
# conv2d_1044 (Conv2D)            (None, None, None, 9 82944       activation_1043[0][0]
# __________________________________________________________________________________________________
# conv2d_1045 (Conv2D)            (None, None, None, 3 6144        average_pooling2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1039 (Batch (None, None, None, 6 192         conv2d_1039[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1041 (Batch (None, None, None, 6 192         conv2d_1041[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1044 (Batch (None, None, None, 9 288         conv2d_1044[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1045 (Batch (None, None, None, 3 96          conv2d_1045[0][0]
# __________________________________________________________________________________________________
# activation_1039 (Activation)    (None, None, None, 6 0           batch_normalization_1039[0][0]
# __________________________________________________________________________________________________
# activation_1041 (Activation)    (None, None, None, 6 0           batch_normalization_1041[0][0]
# __________________________________________________________________________________________________
# activation_1044 (Activation)    (None, None, None, 9 0           batch_normalization_1044[0][0]
# __________________________________________________________________________________________________
# activation_1045 (Activation)    (None, None, None, 3 0           batch_normalization_1045[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_1039[0][0]
#                                                                  activation_1041[0][0]
#                                                                  activation_1044[0][0]
#                                                                  activation_1045[0][0]
# __________________________________________________________________________________________________
# conv2d_1049 (Conv2D)            (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1049 (Batch (None, None, None, 6 192         conv2d_1049[0][0]
# __________________________________________________________________________________________________
# activation_1049 (Activation)    (None, None, None, 6 0           batch_normalization_1049[0][0]
# __________________________________________________________________________________________________
# conv2d_1047 (Conv2D)            (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_1050 (Conv2D)            (None, None, None, 9 55296       activation_1049[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1047 (Batch (None, None, None, 4 144         conv2d_1047[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1050 (Batch (None, None, None, 9 288         conv2d_1050[0][0]
# __________________________________________________________________________________________________
# activation_1047 (Activation)    (None, None, None, 4 0           batch_normalization_1047[0][0]
# __________________________________________________________________________________________________
# activation_1050 (Activation)    (None, None, None, 9 0           batch_normalization_1050[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_100 (AverageP (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_1046 (Conv2D)            (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_1048 (Conv2D)            (None, None, None, 6 76800       activation_1047[0][0]
# __________________________________________________________________________________________________
# conv2d_1051 (Conv2D)            (None, None, None, 9 82944       activation_1050[0][0]
# __________________________________________________________________________________________________
# conv2d_1052 (Conv2D)            (None, None, None, 6 16384       average_pooling2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1046 (Batch (None, None, None, 6 192         conv2d_1046[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1048 (Batch (None, None, None, 6 192         conv2d_1048[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1051 (Batch (None, None, None, 9 288         conv2d_1051[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1052 (Batch (None, None, None, 6 192         conv2d_1052[0][0]
# __________________________________________________________________________________________________
# activation_1046 (Activation)    (None, None, None, 6 0           batch_normalization_1046[0][0]
# __________________________________________________________________________________________________
# activation_1048 (Activation)    (None, None, None, 6 0           batch_normalization_1048[0][0]
# __________________________________________________________________________________________________
# activation_1051 (Activation)    (None, None, None, 9 0           batch_normalization_1051[0][0]
# __________________________________________________________________________________________________
# activation_1052 (Activation)    (None, None, None, 6 0           batch_normalization_1052[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_1046[0][0]
#                                                                  activation_1048[0][0]
#                                                                  activation_1051[0][0]
#                                                                  activation_1052[0][0]
# __________________________________________________________________________________________________
# conv2d_1056 (Conv2D)            (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1056 (Batch (None, None, None, 6 192         conv2d_1056[0][0]
# __________________________________________________________________________________________________
# activation_1056 (Activation)    (None, None, None, 6 0           batch_normalization_1056[0][0]
# __________________________________________________________________________________________________
# conv2d_1054 (Conv2D)            (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_1057 (Conv2D)            (None, None, None, 9 55296       activation_1056[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1054 (Batch (None, None, None, 4 144         conv2d_1054[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1057 (Batch (None, None, None, 9 288         conv2d_1057[0][0]
# __________________________________________________________________________________________________
# activation_1054 (Activation)    (None, None, None, 4 0           batch_normalization_1054[0][0]
# __________________________________________________________________________________________________
# activation_1057 (Activation)    (None, None, None, 9 0           batch_normalization_1057[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_101 (AverageP (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_1053 (Conv2D)            (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_1055 (Conv2D)            (None, None, None, 6 76800       activation_1054[0][0]
# __________________________________________________________________________________________________
# conv2d_1058 (Conv2D)            (None, None, None, 9 82944       activation_1057[0][0]
# __________________________________________________________________________________________________
# conv2d_1059 (Conv2D)            (None, None, None, 6 18432       average_pooling2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1053 (Batch (None, None, None, 6 192         conv2d_1053[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1055 (Batch (None, None, None, 6 192         conv2d_1055[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1058 (Batch (None, None, None, 9 288         conv2d_1058[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1059 (Batch (None, None, None, 6 192         conv2d_1059[0][0]
# __________________________________________________________________________________________________
# activation_1053 (Activation)    (None, None, None, 6 0           batch_normalization_1053[0][0]
# __________________________________________________________________________________________________
# activation_1055 (Activation)    (None, None, None, 6 0           batch_normalization_1055[0][0]
# __________________________________________________________________________________________________
# activation_1058 (Activation)    (None, None, None, 9 0           batch_normalization_1058[0][0]
# __________________________________________________________________________________________________
# activation_1059 (Activation)    (None, None, None, 6 0           batch_normalization_1059[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_1053[0][0]
#                                                                  activation_1055[0][0]
#                                                                  activation_1058[0][0]
#                                                                  activation_1059[0][0]
# __________________________________________________________________________________________________
# conv2d_1061 (Conv2D)            (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1061 (Batch (None, None, None, 6 192         conv2d_1061[0][0]
# __________________________________________________________________________________________________
# activation_1061 (Activation)    (None, None, None, 6 0           batch_normalization_1061[0][0]
# __________________________________________________________________________________________________
# conv2d_1062 (Conv2D)            (None, None, None, 9 55296       activation_1061[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1062 (Batch (None, None, None, 9 288         conv2d_1062[0][0]
# __________________________________________________________________________________________________
# activation_1062 (Activation)    (None, None, None, 9 0           batch_normalization_1062[0][0]
# __________________________________________________________________________________________________
# conv2d_1060 (Conv2D)            (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_1063 (Conv2D)            (None, None, None, 9 82944       activation_1062[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1060 (Batch (None, None, None, 3 1152        conv2d_1060[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1063 (Batch (None, None, None, 9 288         conv2d_1063[0][0]
# __________________________________________________________________________________________________
# activation_1060 (Activation)    (None, None, None, 3 0           batch_normalization_1060[0][0]
# __________________________________________________________________________________________________
# activation_1063 (Activation)    (None, None, None, 9 0           batch_normalization_1063[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_1060[0][0]
#                                                                  activation_1063[0][0]
#                                                                  max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_1068 (Conv2D)            (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1068 (Batch (None, None, None, 1 384         conv2d_1068[0][0]
# __________________________________________________________________________________________________
# activation_1068 (Activation)    (None, None, None, 1 0           batch_normalization_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1069 (Conv2D)            (None, None, None, 1 114688      activation_1068[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1069 (Batch (None, None, None, 1 384         conv2d_1069[0][0]
# __________________________________________________________________________________________________
# activation_1069 (Activation)    (None, None, None, 1 0           batch_normalization_1069[0][0]
# __________________________________________________________________________________________________
# conv2d_1065 (Conv2D)            (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_1070 (Conv2D)            (None, None, None, 1 114688      activation_1069[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1065 (Batch (None, None, None, 1 384         conv2d_1065[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1070 (Batch (None, None, None, 1 384         conv2d_1070[0][0]
# __________________________________________________________________________________________________
# activation_1065 (Activation)    (None, None, None, 1 0           batch_normalization_1065[0][0]
# __________________________________________________________________________________________________
# activation_1070 (Activation)    (None, None, None, 1 0           batch_normalization_1070[0][0]
# __________________________________________________________________________________________________
# conv2d_1066 (Conv2D)            (None, None, None, 1 114688      activation_1065[0][0]
# __________________________________________________________________________________________________
# conv2d_1071 (Conv2D)            (None, None, None, 1 114688      activation_1070[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1066 (Batch (None, None, None, 1 384         conv2d_1066[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1071 (Batch (None, None, None, 1 384         conv2d_1071[0][0]
# __________________________________________________________________________________________________
# activation_1066 (Activation)    (None, None, None, 1 0           batch_normalization_1066[0][0]
# __________________________________________________________________________________________________
# activation_1071 (Activation)    (None, None, None, 1 0           batch_normalization_1071[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_102 (AverageP (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_1064 (Conv2D)            (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_1067 (Conv2D)            (None, None, None, 1 172032      activation_1066[0][0]
# __________________________________________________________________________________________________
# conv2d_1072 (Conv2D)            (None, None, None, 1 172032      activation_1071[0][0]
# __________________________________________________________________________________________________
# conv2d_1073 (Conv2D)            (None, None, None, 1 147456      average_pooling2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1064 (Batch (None, None, None, 1 576         conv2d_1064[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1067 (Batch (None, None, None, 1 576         conv2d_1067[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1072 (Batch (None, None, None, 1 576         conv2d_1072[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1073 (Batch (None, None, None, 1 576         conv2d_1073[0][0]
# __________________________________________________________________________________________________
# activation_1064 (Activation)    (None, None, None, 1 0           batch_normalization_1064[0][0]
# __________________________________________________________________________________________________
# activation_1067 (Activation)    (None, None, None, 1 0           batch_normalization_1067[0][0]
# __________________________________________________________________________________________________
# activation_1072 (Activation)    (None, None, None, 1 0           batch_normalization_1072[0][0]
# __________________________________________________________________________________________________
# activation_1073 (Activation)    (None, None, None, 1 0           batch_normalization_1073[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_1064[0][0]
#                                                                  activation_1067[0][0]
#                                                                  activation_1072[0][0]
#                                                                  activation_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1078 (Conv2D)            (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1078 (Batch (None, None, None, 1 480         conv2d_1078[0][0]
# __________________________________________________________________________________________________
# activation_1078 (Activation)    (None, None, None, 1 0           batch_normalization_1078[0][0]
# __________________________________________________________________________________________________
# conv2d_1079 (Conv2D)            (None, None, None, 1 179200      activation_1078[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1079 (Batch (None, None, None, 1 480         conv2d_1079[0][0]
# __________________________________________________________________________________________________
# activation_1079 (Activation)    (None, None, None, 1 0           batch_normalization_1079[0][0]
# __________________________________________________________________________________________________
# conv2d_1075 (Conv2D)            (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_1080 (Conv2D)            (None, None, None, 1 179200      activation_1079[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1075 (Batch (None, None, None, 1 480         conv2d_1075[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1080 (Batch (None, None, None, 1 480         conv2d_1080[0][0]
# __________________________________________________________________________________________________
# activation_1075 (Activation)    (None, None, None, 1 0           batch_normalization_1075[0][0]
# __________________________________________________________________________________________________
# activation_1080 (Activation)    (None, None, None, 1 0           batch_normalization_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1076 (Conv2D)            (None, None, None, 1 179200      activation_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1081 (Conv2D)            (None, None, None, 1 179200      activation_1080[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1076 (Batch (None, None, None, 1 480         conv2d_1076[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1081 (Batch (None, None, None, 1 480         conv2d_1081[0][0]
# __________________________________________________________________________________________________
# activation_1076 (Activation)    (None, None, None, 1 0           batch_normalization_1076[0][0]
# __________________________________________________________________________________________________
# activation_1081 (Activation)    (None, None, None, 1 0           batch_normalization_1081[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_103 (AverageP (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_1074 (Conv2D)            (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_1077 (Conv2D)            (None, None, None, 1 215040      activation_1076[0][0]
# __________________________________________________________________________________________________
# conv2d_1082 (Conv2D)            (None, None, None, 1 215040      activation_1081[0][0]
# __________________________________________________________________________________________________
# conv2d_1083 (Conv2D)            (None, None, None, 1 147456      average_pooling2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1074 (Batch (None, None, None, 1 576         conv2d_1074[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1077 (Batch (None, None, None, 1 576         conv2d_1077[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1082 (Batch (None, None, None, 1 576         conv2d_1082[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1083 (Batch (None, None, None, 1 576         conv2d_1083[0][0]
# __________________________________________________________________________________________________
# activation_1074 (Activation)    (None, None, None, 1 0           batch_normalization_1074[0][0]
# __________________________________________________________________________________________________
# activation_1077 (Activation)    (None, None, None, 1 0           batch_normalization_1077[0][0]
# __________________________________________________________________________________________________
# activation_1082 (Activation)    (None, None, None, 1 0           batch_normalization_1082[0][0]
# __________________________________________________________________________________________________
# activation_1083 (Activation)    (None, None, None, 1 0           batch_normalization_1083[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_1074[0][0]
#                                                                  activation_1077[0][0]
#                                                                  activation_1082[0][0]
#                                                                  activation_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1088 (Conv2D)            (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1088 (Batch (None, None, None, 1 480         conv2d_1088[0][0]
# __________________________________________________________________________________________________
# activation_1088 (Activation)    (None, None, None, 1 0           batch_normalization_1088[0][0]
# __________________________________________________________________________________________________
# conv2d_1089 (Conv2D)            (None, None, None, 1 179200      activation_1088[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1089 (Batch (None, None, None, 1 480         conv2d_1089[0][0]
# __________________________________________________________________________________________________
# activation_1089 (Activation)    (None, None, None, 1 0           batch_normalization_1089[0][0]
# __________________________________________________________________________________________________
# conv2d_1085 (Conv2D)            (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_1090 (Conv2D)            (None, None, None, 1 179200      activation_1089[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1085 (Batch (None, None, None, 1 480         conv2d_1085[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1090 (Batch (None, None, None, 1 480         conv2d_1090[0][0]
# __________________________________________________________________________________________________
# activation_1085 (Activation)    (None, None, None, 1 0           batch_normalization_1085[0][0]
# __________________________________________________________________________________________________
# activation_1090 (Activation)    (None, None, None, 1 0           batch_normalization_1090[0][0]
# __________________________________________________________________________________________________
# conv2d_1086 (Conv2D)            (None, None, None, 1 179200      activation_1085[0][0]
# __________________________________________________________________________________________________
# conv2d_1091 (Conv2D)            (None, None, None, 1 179200      activation_1090[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1086 (Batch (None, None, None, 1 480         conv2d_1086[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1091 (Batch (None, None, None, 1 480         conv2d_1091[0][0]
# __________________________________________________________________________________________________
# activation_1086 (Activation)    (None, None, None, 1 0           batch_normalization_1086[0][0]
# __________________________________________________________________________________________________
# activation_1091 (Activation)    (None, None, None, 1 0           batch_normalization_1091[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_104 (AverageP (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_1084 (Conv2D)            (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_1087 (Conv2D)            (None, None, None, 1 215040      activation_1086[0][0]
# __________________________________________________________________________________________________
# conv2d_1092 (Conv2D)            (None, None, None, 1 215040      activation_1091[0][0]
# __________________________________________________________________________________________________
# conv2d_1093 (Conv2D)            (None, None, None, 1 147456      average_pooling2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1084 (Batch (None, None, None, 1 576         conv2d_1084[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1087 (Batch (None, None, None, 1 576         conv2d_1087[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1092 (Batch (None, None, None, 1 576         conv2d_1092[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1093 (Batch (None, None, None, 1 576         conv2d_1093[0][0]
# __________________________________________________________________________________________________
# activation_1084 (Activation)    (None, None, None, 1 0           batch_normalization_1084[0][0]
# __________________________________________________________________________________________________
# activation_1087 (Activation)    (None, None, None, 1 0           batch_normalization_1087[0][0]
# __________________________________________________________________________________________________
# activation_1092 (Activation)    (None, None, None, 1 0           batch_normalization_1092[0][0]
# __________________________________________________________________________________________________
# activation_1093 (Activation)    (None, None, None, 1 0           batch_normalization_1093[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_1084[0][0]
#                                                                  activation_1087[0][0]
#                                                                  activation_1092[0][0]
#                                                                  activation_1093[0][0]
# __________________________________________________________________________________________________
# conv2d_1098 (Conv2D)            (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1098 (Batch (None, None, None, 1 576         conv2d_1098[0][0]
# __________________________________________________________________________________________________
# activation_1098 (Activation)    (None, None, None, 1 0           batch_normalization_1098[0][0]
# __________________________________________________________________________________________________
# conv2d_1099 (Conv2D)            (None, None, None, 1 258048      activation_1098[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1099 (Batch (None, None, None, 1 576         conv2d_1099[0][0]
# __________________________________________________________________________________________________
# activation_1099 (Activation)    (None, None, None, 1 0           batch_normalization_1099[0][0]
# __________________________________________________________________________________________________
# conv2d_1095 (Conv2D)            (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_1100 (Conv2D)            (None, None, None, 1 258048      activation_1099[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1095 (Batch (None, None, None, 1 576         conv2d_1095[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1100 (Batch (None, None, None, 1 576         conv2d_1100[0][0]
# __________________________________________________________________________________________________
# activation_1095 (Activation)    (None, None, None, 1 0           batch_normalization_1095[0][0]
# __________________________________________________________________________________________________
# activation_1100 (Activation)    (None, None, None, 1 0           batch_normalization_1100[0][0]
# __________________________________________________________________________________________________
# conv2d_1096 (Conv2D)            (None, None, None, 1 258048      activation_1095[0][0]
# __________________________________________________________________________________________________
# conv2d_1101 (Conv2D)            (None, None, None, 1 258048      activation_1100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1096 (Batch (None, None, None, 1 576         conv2d_1096[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1101 (Batch (None, None, None, 1 576         conv2d_1101[0][0]
# __________________________________________________________________________________________________
# activation_1096 (Activation)    (None, None, None, 1 0           batch_normalization_1096[0][0]
# __________________________________________________________________________________________________
# activation_1101 (Activation)    (None, None, None, 1 0           batch_normalization_1101[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_105 (AverageP (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_1094 (Conv2D)            (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_1097 (Conv2D)            (None, None, None, 1 258048      activation_1096[0][0]
# __________________________________________________________________________________________________
# conv2d_1102 (Conv2D)            (None, None, None, 1 258048      activation_1101[0][0]
# __________________________________________________________________________________________________
# conv2d_1103 (Conv2D)            (None, None, None, 1 147456      average_pooling2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1094 (Batch (None, None, None, 1 576         conv2d_1094[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1097 (Batch (None, None, None, 1 576         conv2d_1097[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1102 (Batch (None, None, None, 1 576         conv2d_1102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1103 (Batch (None, None, None, 1 576         conv2d_1103[0][0]
# __________________________________________________________________________________________________
# activation_1094 (Activation)    (None, None, None, 1 0           batch_normalization_1094[0][0]
# __________________________________________________________________________________________________
# activation_1097 (Activation)    (None, None, None, 1 0           batch_normalization_1097[0][0]
# __________________________________________________________________________________________________
# activation_1102 (Activation)    (None, None, None, 1 0           batch_normalization_1102[0][0]
# __________________________________________________________________________________________________
# activation_1103 (Activation)    (None, None, None, 1 0           batch_normalization_1103[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_1094[0][0]
#                                                                  activation_1097[0][0]
#                                                                  activation_1102[0][0]
#                                                                  activation_1103[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_1108 (Batch (None, None, None, 1 576         conv2d_1108[0][0]
# __________________________________________________________________________________________________
# activation_1104 (Activation)    (None, None, None, 1 0           batch_normalization_1104[0][0]
# __________________________________________________________________________________________________
# activation_1108 (Activation)    (None, None, None, 1 0           batch_normalization_1108[0][0]
# __________________________________________________________________________________________________
# conv2d_1105 (Conv2D)            (None, None, None, 3 552960      activation_1104[0][0]
# __________________________________________________________________________________________________
# conv2d_1109 (Conv2D)            (None, None, None, 1 331776      activation_1108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1105 (Batch (None, None, None, 3 960         conv2d_1105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1109 (Batch (None, None, None, 1 576         conv2d_1109[0][0]
# __________________________________________________________________________________________________
# activation_1105 (Activation)    (None, None, None, 3 0           batch_normalization_1105[0][0]
# __________________________________________________________________________________________________
# activation_1109 (Activation)    (None, None, None, 1 0           batch_normalization_1109[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_1105[0][0]
#                                                                  activation_1109[0][0]
#                                                                  max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_1114 (Conv2D)            (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1114 (Batch (None, None, None, 4 1344        conv2d_1114[0][0]
# __________________________________________________________________________________________________
# activation_1114 (Activation)    (None, None, None, 4 0           batch_normalization_1114[0][0]
# __________________________________________________________________________________________________
# conv2d_1111 (Conv2D)            (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_1115 (Conv2D)            (None, None, None, 3 1548288     activation_1114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1111 (Batch (None, None, None, 3 1152        conv2d_1111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1115 (Batch (None, None, None, 3 1152        conv2d_1115[0][0]
# __________________________________________________________________________________________________
# activation_1111 (Activation)    (None, None, None, 3 0           batch_normalization_1111[0][0]
# __________________________________________________________________________________________________
# activation_1115 (Activation)    (None, None, None, 3 0           batch_normalization_1115[0][0]
# __________________________________________________________________________________________________
# conv2d_1112 (Conv2D)            (None, None, None, 3 442368      activation_1111[0][0]
# __________________________________________________________________________________________________
# conv2d_1113 (Conv2D)            (None, None, None, 3 442368      activation_1111[0][0]
# __________________________________________________________________________________________________
# conv2d_1116 (Conv2D)            (None, None, None, 3 442368      activation_1115[0][0]
# __________________________________________________________________________________________________
# conv2d_1117 (Conv2D)            (None, None, None, 3 442368      activation_1115[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_106 (AverageP (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_1110 (Conv2D)            (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1112 (Batch (None, None, None, 3 1152        conv2d_1112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1113 (Batch (None, None, None, 3 1152        conv2d_1113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1116 (Batch (None, None, None, 3 1152        conv2d_1116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1117 (Batch (None, None, None, 3 1152        conv2d_1117[0][0]
# __________________________________________________________________________________________________
# conv2d_1118 (Conv2D)            (None, None, None, 1 245760      average_pooling2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1110 (Batch (None, None, None, 3 960         conv2d_1110[0][0]
# __________________________________________________________________________________________________
# activation_1112 (Activation)    (None, None, None, 3 0           batch_normalization_1112[0][0]
# __________________________________________________________________________________________________
# activation_1113 (Activation)    (None, None, None, 3 0           batch_normalization_1113[0][0]
# __________________________________________________________________________________________________
# activation_1116 (Activation)    (None, None, None, 3 0           batch_normalization_1116[0][0]
# __________________________________________________________________________________________________
# activation_1117 (Activation)    (None, None, None, 3 0           batch_normalization_1117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1118 (Batch (None, None, None, 1 576         conv2d_1118[0][0]
# __________________________________________________________________________________________________
# activation_1110 (Activation)    (None, None, None, 3 0           batch_normalization_1110[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_1112[0][0]
#                                                                  activation_1113[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, None, None, 7 0           activation_1116[0][0]
#                                                                  activation_1117[0][0]
# __________________________________________________________________________________________________
# activation_1118 (Activation)    (None, None, None, 1 0           batch_normalization_1118[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_1110[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_22[0][0]
#                                                                  activation_1118[0][0]
# __________________________________________________________________________________________________
# conv2d_1123 (Conv2D)            (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1123 (Batch (None, None, None, 4 1344        conv2d_1123[0][0]
# __________________________________________________________________________________________________
# activation_1123 (Activation)    (None, None, None, 4 0           batch_normalization_1123[0][0]
# __________________________________________________________________________________________________
# conv2d_1120 (Conv2D)            (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_1124 (Conv2D)            (None, None, None, 3 1548288     activation_1123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1120 (Batch (None, None, None, 3 1152        conv2d_1120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1124 (Batch (None, None, None, 3 1152        conv2d_1124[0][0]
# __________________________________________________________________________________________________
# activation_1120 (Activation)    (None, None, None, 3 0           batch_normalization_1120[0][0]
# __________________________________________________________________________________________________
# activation_1124 (Activation)    (None, None, None, 3 0           batch_normalization_1124[0][0]
# __________________________________________________________________________________________________
# conv2d_1121 (Conv2D)            (None, None, None, 3 442368      activation_1120[0][0]
# __________________________________________________________________________________________________
# conv2d_1122 (Conv2D)            (None, None, None, 3 442368      activation_1120[0][0]
# __________________________________________________________________________________________________
# conv2d_1125 (Conv2D)            (None, None, None, 3 442368      activation_1124[0][0]
# __________________________________________________________________________________________________
# conv2d_1126 (Conv2D)            (None, None, None, 3 442368      activation_1124[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_107 (AverageP (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_1119 (Conv2D)            (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1121 (Batch (None, None, None, 3 1152        conv2d_1121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1122 (Batch (None, None, None, 3 1152        conv2d_1122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1125 (Batch (None, None, None, 3 1152        conv2d_1125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1126 (Batch (None, None, None, 3 1152        conv2d_1126[0][0]
# __________________________________________________________________________________________________
# conv2d_1127 (Conv2D)            (None, None, None, 1 393216      average_pooling2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1119 (Batch (None, None, None, 3 960         conv2d_1119[0][0]
# __________________________________________________________________________________________________
# activation_1121 (Activation)    (None, None, None, 3 0           batch_normalization_1121[0][0]
# __________________________________________________________________________________________________
# activation_1122 (Activation)    (None, None, None, 3 0           batch_normalization_1122[0][0]
# __________________________________________________________________________________________________
# activation_1125 (Activation)    (None, None, None, 3 0           batch_normalization_1125[0][0]
# __________________________________________________________________________________________________
# activation_1126 (Activation)    (None, None, None, 3 0           batch_normalization_1126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1127 (Batch (None, None, None, 1 576         conv2d_1127[0][0]
# __________________________________________________________________________________________________
# activation_1119 (Activation)    (None, None, None, 3 0           batch_normalization_1119[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_1121[0][0]
#                                                                  activation_1122[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, None, None, 7 0           activation_1125[0][0]
#                                                                  activation_1126[0][0]
# __________________________________________________________________________________________________
# activation_1127 (Activation)    (None, None, None, 1 0           batch_normalization_1127[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_1119[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_23[0][0]
#                                                                  activation_1127[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
for layer in inception_model.layers:
    print(layer.name, layer.trainable)
# Out:
# input_12 True
# conv2d_1034 True
# batch_normalization_1034 True
# activation_1034 True
# conv2d_1035 True
# batch_normalization_1035 True
# activation_1035 True
# conv2d_1036 True
# batch_normalization_1036 True
# activation_1036 True
# max_pooling2d_44 True
# conv2d_1037 True
# batch_normalization_1037 True
# activation_1037 True
# conv2d_1038 True
# batch_normalization_1038 True
# activation_1038 True
# max_pooling2d_45 True
# conv2d_1042 True
# batch_normalization_1042 True
# activation_1042 True
# conv2d_1040 True
# conv2d_1043 True
# batch_normalization_1040 True
# batch_normalization_1043 True
# activation_1040 True
# activation_1043 True
# average_pooling2d_99 True
# conv2d_1039 True
# conv2d_1041 True
# conv2d_1044 True
# conv2d_1045 True
# batch_normalization_1039 True
# batch_normalization_1041 True
# batch_normalization_1044 True
# batch_normalization_1045 True
# activation_1039 True
# activation_1041 True
# activation_1044 True
# activation_1045 True
# mixed0 True
# conv2d_1049 True
# batch_normalization_1049 True
# activation_1049 True
# conv2d_1047 True
# conv2d_1050 True
# batch_normalization_1047 True
# batch_normalization_1050 True
# activation_1047 True
# activation_1050 True
# average_pooling2d_100 True
# conv2d_1046 True
# conv2d_1048 True
# conv2d_1051 True
# conv2d_1052 True
# batch_normalization_1046 True
# batch_normalization_1048 True
# batch_normalization_1051 True
# batch_normalization_1052 True
# activation_1046 True
# activation_1048 True
# activation_1051 True
# activation_1052 True
# mixed1 True
# conv2d_1056 True
# batch_normalization_1056 True
# activation_1056 True
# conv2d_1054 True
# conv2d_1057 True
# batch_normalization_1054 True
# batch_normalization_1057 True
# activation_1054 True
# activation_1057 True
# average_pooling2d_101 True
# conv2d_1053 True
# conv2d_1055 True
# conv2d_1058 True
# conv2d_1059 True
# batch_normalization_1053 True
# batch_normalization_1055 True
# batch_normalization_1058 True
# batch_normalization_1059 True
# activation_1053 True
# activation_1055 True
# activation_1058 True
# activation_1059 True
# mixed2 True
# conv2d_1061 True
# batch_normalization_1061 True
# activation_1061 True
# conv2d_1062 True
# batch_normalization_1062 True
# activation_1062 True
# conv2d_1060 True
# conv2d_1063 True
# batch_normalization_1060 True
# batch_normalization_1063 True
# activation_1060 True
# activation_1063 True
# max_pooling2d_46 True
# mixed3 True
# conv2d_1068 True
# batch_normalization_1068 True
# activation_1068 True
# conv2d_1069 True
# batch_normalization_1069 True
# activation_1069 True
# conv2d_1065 True
# conv2d_1070 True
# batch_normalization_1065 True
# batch_normalization_1070 True
# activation_1065 True
# activation_1070 True
# conv2d_1066 True
# conv2d_1071 True
# batch_normalization_1066 True
# batch_normalization_1071 True
# activation_1066 True
# activation_1071 True
# average_pooling2d_102 True
# conv2d_1064 True
# conv2d_1067 True
# conv2d_1072 True
# conv2d_1073 True
# batch_normalization_1064 True
# batch_normalization_1067 True
# batch_normalization_1072 True
# batch_normalization_1073 True
# activation_1064 True
# activation_1067 True
# activation_1072 True
# activation_1073 True
# mixed4 True
# conv2d_1078 True
# batch_normalization_1078 True
# activation_1078 True
# conv2d_1079 True
# batch_normalization_1079 True
# activation_1079 True
# conv2d_1075 True
# conv2d_1080 True
# batch_normalization_1075 True
# batch_normalization_1080 True
# activation_1075 True
# activation_1080 True
# conv2d_1076 True
# conv2d_1081 True
# batch_normalization_1076 True
# batch_normalization_1081 True
# activation_1076 True
# activation_1081 True
# average_pooling2d_103 True
# conv2d_1074 True
# conv2d_1077 True
# conv2d_1082 True
# conv2d_1083 True
# batch_normalization_1074 True
# batch_normalization_1077 True
# batch_normalization_1082 True
# batch_normalization_1083 True
# activation_1074 True
# activation_1077 True
# activation_1082 True
# activation_1083 True
# mixed5 True
# conv2d_1088 True
# batch_normalization_1088 True
# activation_1088 True
# conv2d_1089 True
# batch_normalization_1089 True
# activation_1089 True
# conv2d_1085 True
# conv2d_1090 True
# batch_normalization_1085 True
# batch_normalization_1090 True
# activation_1085 True
# activation_1090 True
# conv2d_1086 True
# conv2d_1091 True
# batch_normalization_1086 True
# batch_normalization_1091 True
# activation_1086 True
# activation_1091 True
# average_pooling2d_104 True
# conv2d_1084 True
# conv2d_1087 True
# conv2d_1092 True
# conv2d_1093 True
# batch_normalization_1084 True
# batch_normalization_1087 True
# batch_normalization_1092 True
# batch_normalization_1093 True
# activation_1084 True
# activation_1087 True
# activation_1092 True
# activation_1093 True
# mixed6 True
# conv2d_1098 True
# batch_normalization_1098 True
# activation_1098 True
# conv2d_1099 True
# batch_normalization_1099 True
# activation_1099 True
# conv2d_1095 True
# conv2d_1100 True
# batch_normalization_1095 True
# batch_normalization_1100 True
# activation_1095 True
# activation_1100 True
# conv2d_1096 True
# conv2d_1101 True
# batch_normalization_1096 True
# batch_normalization_1101 True
# activation_1096 True
# activation_1101 True
# average_pooling2d_105 True
# conv2d_1094 True
# conv2d_1097 True
# conv2d_1102 True
# conv2d_1103 True
# batch_normalization_1094 True
# batch_normalization_1097 True
# batch_normalization_1102 True
# batch_normalization_1103 True
# activation_1094 True
# activation_1097 True
# activation_1102 True
# activation_1103 True
# mixed7 True
# conv2d_1106 True
# batch_normalization_1106 True
# activation_1106 True
# conv2d_1107 True
# batch_normalization_1107 True
# activation_1107 True
# conv2d_1104 True
# conv2d_1108 True
# batch_normalization_1104 True
# batch_normalization_1108 True
# activation_1104 True
# activation_1108 True
# conv2d_1105 True
# conv2d_1109 True
# batch_normalization_1105 True
# batch_normalization_1109 True
# activation_1105 True
# activation_1109 True
# max_pooling2d_47 True
# mixed8 True
# conv2d_1114 True
# batch_normalization_1114 True
# activation_1114 True
# conv2d_1111 True
# conv2d_1115 True
# batch_normalization_1111 True
# batch_normalization_1115 True
# activation_1111 True
# activation_1115 True
# conv2d_1112 True
# conv2d_1113 True
# conv2d_1116 True
# conv2d_1117 True
# average_pooling2d_106 True
# conv2d_1110 True
# batch_normalization_1112 True
# batch_normalization_1113 True
# batch_normalization_1116 True
# batch_normalization_1117 True
# conv2d_1118 True
# batch_normalization_1110 True
# activation_1112 True
# activation_1113 True
# activation_1116 True
# activation_1117 True
# batch_normalization_1118 True
# activation_1110 True
# mixed9_0 True
# concatenate_22 True
# activation_1118 True
# mixed9 True
# conv2d_1123 True
# batch_normalization_1123 True
# activation_1123 True
# conv2d_1120 True
# conv2d_1124 True
# batch_normalization_1120 True
# batch_normalization_1124 True
# activation_1120 True
# activation_1124 True
# conv2d_1121 True
# conv2d_1122 True
# conv2d_1125 True
# conv2d_1126 True
# average_pooling2d_107 True
# conv2d_1119 True
# batch_normalization_1121 True
# batch_normalization_1122 True
# batch_normalization_1125 True
# batch_normalization_1126 True
# conv2d_1127 True
# batch_normalization_1119 True
# activation_1121 True
# activation_1122 True
# activation_1125 True
# activation_1126 True
# batch_normalization_1127 True
# activation_1119 True
# mixed9_1 True
# concatenate_23 True
# activation_1127 True
# mixed10 True

# %%
new_model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 75, 75, 3)]       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_avg_pool_layer (Globa (None, 2048)              0
# _________________________________________________________________
# output_layer (Dense)         (None, 43)                88107
# =================================================================
# Total params: 21,890,891
# Trainable params: 21,856,459
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
new_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = new_model.fit_generator(
    train_generator,
    validation_data=valid_generator,
    validation_steps=int(0.25*len(valid_generator)),
    epochs=15
)
# Out:
# Epoch 1/15
# 919/919 [==============================] - 137s 141ms/step - loss: 0.6097 - accuracy: 0.8484 - val_loss: 0.0871 - val_accuracy: 0.9778
# Epoch 2/15
# 919/919 [==============================] - 128s 140ms/step - loss: 0.1225 - accuracy: 0.9697 - val_loss: 0.0469 - val_accuracy: 0.9889
# Epoch 3/15
# 919/919 [==============================] - 121s 131ms/step - loss: 0.0820 - accuracy: 0.9818 - val_loss: 0.0776 - val_accuracy: 0.9790
# Epoch 4/15
# 919/919 [==============================] - 131s 142ms/step - loss: 0.0566 - accuracy: 0.9865 - val_loss: 0.0599 - val_accuracy: 0.9848
# Epoch 5/15
# 919/919 [==============================] - 165s 180ms/step - loss: 0.0578 - accuracy: 0.9877 - val_loss: 0.1022 - val_accuracy: 0.9774
# Epoch 6/15
# 919/919 [==============================] - 174s 189ms/step - loss: 0.0791 - accuracy: 0.9822 - val_loss: 0.0347 - val_accuracy: 0.9914
# Epoch 7/15
# 919/919 [==============================] - 181s 197ms/step - loss: 0.0282 - accuracy: 0.9929 - val_loss: 0.0413 - val_accuracy: 0.9881
# Epoch 8/15
# 919/919 [==============================] - 190s 206ms/step - loss: 0.0415 - accuracy: 0.9908 - val_loss: 0.0243 - val_accuracy: 0.9938
# Epoch 9/15
# 919/919 [==============================] - 167s 182ms/step - loss: 0.0308 - accuracy: 0.9922 - val_loss: 0.0202 - val_accuracy: 0.9947
# Epoch 10/15
# 919/919 [==============================] - 170s 185ms/step - loss: 0.0282 - accuracy: 0.9927 - val_loss: 0.0127 - val_accuracy: 0.9971
# Epoch 11/15
# 919/919 [==============================] - 163s 178ms/step - loss: 0.0501 - accuracy: 0.9903 - val_loss: 0.0348 - val_accuracy: 0.9938
# Epoch 12/15
# 919/919 [==============================] - 173s 188ms/step - loss: 0.0121 - accuracy: 0.9971 - val_loss: 0.0122 - val_accuracy: 0.9963
# Epoch 13/15
# 919/919 [==============================] - 170s 185ms/step - loss: 0.0236 - accuracy: 0.9944 - val_loss: 0.0165 - val_accuracy: 0.9951
# Epoch 14/15
# 919/919 [==============================] - 214s 233ms/step - loss: 0.0392 - accuracy: 0.9932 - val_loss: 0.0388 - val_accuracy: 0.9910
# Epoch 15/15
# 919/919 [==============================] - 189s 206ms/step - loss: 0.0380 - accuracy: 0.9919 - val_loss: 0.1004 - val_accuracy: 0.9844

# %%
new_model.evaluate(test_generator)
# Out:
# 395/395 [==============================] - 18s 44ms/step - loss: 0.2879 - accuracy: 0.9573
# [0.2879076302051544, 0.9573238492012024]
